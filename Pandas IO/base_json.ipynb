# %%
import pandas as pd

# %%
dados = pd.read_json('./produtos.json')
df = pd.DataFrame(dados)
df
# Out:
#    id               nome categoria   preco  estoque       fornecedor
# 0   1     Filtro de Óleo     Motor   35.50       20  AutoPartes LTDA
# 1   2        Pneu Aro 16     Rodas  450.00       15      Pneus e Cia
# 2   3       Bateria 60Ah  Elétrica  520.90        8        EletrAuto
# 3   4  Pastilha de Freio    Freios  120.75       25      FreioSeguro
# 4   5   Velas de Ignição     Motor   75.00       30  AutoPartes LTDA

# %%
json_obj = {
    'ID': '01',
    'Faixa_etaria': '55-59',
    'Sexo_biologico': 'Feminino',
    'Saude': {'Dificuldade_caminhar': 'Nao',
              'Atividade_fisica': 'Sim',
              'IMC': 16.6,
              'Doenca_cardiaca': 'Nao',
          }
      }

# %%
pd.json_normalize(json_obj)
# Out:
#    ID Faixa_etaria Sexo_biologico Saude.Dificuldade_caminhar  \
# 0  01        55-59       Feminino                        Nao
#
#   Saude.Atividade_fisica  Saude.IMC Saude.Doenca_cardiaca
# 0                    Sim       16.6                   Nao

# %%
json_list = [
    {
        'ID': '01',
        'Faixa_etaria': '55-59',
        'Sexo_biologico': 'Feminino',
        'Saude': {'Dificuldade_caminhar': 'Nao',
                  'Atividade_fisica': 'Sim',
                  'IMC': 16.6,
                  'Doenca_cardiaca': 'Nao',
              }
      },
      {
        'ID': '02',
        'Faixa_etaria': '80 ou +',
        'Sexo_biologico': 'Feminino',
        'Saude': {'Dificuldade_caminhar': 'Nao',
                  'Atividade_fisica': 'Sim',
                  'IMC': 20.34,
                  'Doenca_cardiaca': 'Sim'
                }
       }
       ]

# %%
pd.json_normalize(json_list)
# Out:
#    ID Faixa_etaria Sexo_biologico Saude.Dificuldade_caminhar  \
# 0  01        55-59       Feminino                        Nao
# 1  02      80 ou +       Feminino                        Nao
#
#   Saude.Atividade_fisica  Saude.IMC Saude.Doenca_cardiaca
# 0                    Sim      16.60                   Nao
# 1                    Sim      20.34                   Sim

# %%
dados_dict = {
  "Pesquisa": "Principais Indicadores de Doenca Cardiaca",
  "Ano": 2020,
  "Pacientes": [
    {
      "ID": "01",
      "Faixa_etaria": "55-59",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 16.6,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 3,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 5,
      "Problemas_saude": [
        "Diabetes",
        "Asma",
        "Cancer_pele"
      ]
    },
    {
      "ID": "02",
      "Faixa_etaria": "80 ou +",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 20.34,
      "Fumante": "Nao",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 0,
      "Saude_mental": 0,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 7,
      "Problemas_saude": [
        "AVC"
      ]
    },
    {
      "ID": "03",
      "Faixa_etaria": "65-69",
      "Sexo_biologico": "Masculino",
      "Raça": "Branca",
      "IMC": 26.58,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 20,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 8,
      "Problemas_saude": [
        "diabetes",
        "Asma"
      ]
    }
  ]
}

# %%
pd.json_normalize(dados_dict)
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  [{'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_b...

# %%
dados_pacientes = pd.json_normalize(dados_dict['Pacientes'])
dados_pacientes
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
dados_pacientes.to_csv('dados_pacientes.csv')

# %%
dados_pacientes.to_json('dados_pacientes.json')
